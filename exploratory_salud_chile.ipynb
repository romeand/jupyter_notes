# %%
import os
print(os.getcwd())
# Out:
# c:\Users\rome_\ttpractice\jupyter_notebooks

# %%
import pandas as pd

# %%
salud2018 = pd.read_csv(r"C:\Users\rome_\OneDrive\Documentos\Activities,Trabajos y Schule\tt Files\Data set salud chile\EGRE_DATOS_ABIERTOS_2018.csv", encoding="latin-1", sep=";", low_memory=False)
salud2019 = pd.read_csv(r"C:\Users\rome_\OneDrive\Documentos\Activities,Trabajos y Schule\tt Files\Data set salud chile\EGRE_DATOS_ABIERTOS_2019.csv", encoding="latin-1", sep=";", low_memory=False)
salud2020 = pd.read_csv(r"C:\Users\rome_\OneDrive\Documentos\Activities,Trabajos y Schule\tt Files\Data set salud chile\EGRE_DATOS_ABIERTOS_2020.csv", encoding="latin-1", sep=";", low_memory=False)

# %%
salud2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111307 entries, 0 to 111306
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   PERTENENCIA_ESTABLECIMIENTO_SALUD  111307 non-null  object
#  1   SEXO                               111307 non-null  object
#  2   GRUPO_EDAD                         111307 non-null  object
#  3   ETNIA                              111307 non-null  object
#  4   GLOSA_PAIS_ORIGEN                  111307 non-null  object
#  5   COMUNA_RESIDENCIA                  111307 non-null  int64
#  6   GLOSA_COMUNA_RESIDENCIA            111307 non-null  object
#  7   REGION_RESIDENCIA                  111307 non-null  object
#  8   GLOSA_REGION_RESIDENCIA            111307 non-null  object
#  9   PREVISION                          111307 non-null  object
#  10  GLOSA_PREVISION                    111307 non-null  object
# ...

# %%
salud2018.head()
# Out:
#                    PERTENENCIA_ESTABLECIMIENTO_SALUD    SEXO GRUPO_EDAD  \
# 0  No Pertenecientes al Sistema Nacional de Servi...  HOMBRE      1 a 9
# 1  No Pertenecientes al Sistema Nacional de Servi...  HOMBRE      1 a 9
# 2  No Pertenecientes al Sistema Nacional de Servi...  HOMBRE      1 a 9
# 3  No Pertenecientes al Sistema Nacional de Servi...  HOMBRE      1 a 9
# 4  No Pertenecientes al Sistema Nacional de Servi...  HOMBRE      1 a 9
#
#                                ETNIA GLOSA_PAIS_ORIGEN  COMUNA_RESIDENCIA  \
# 0  No se identifica con alguna etnia           Chileno               1101
# 1  No se identifica con alguna etnia           Chileno               1101
# 2  No se identifica con alguna etnia           Chileno               1101
# 3  No se identifica con alguna etnia           Chileno               1101
# 4  No se identifica con alguna etnia           Chileno               1101
#
#   GLOSA_COMUNA_RESIDENCIA REGION_RESIDENCIA GLOSA_REGION_RESIDENCIA PREVISION  \
# ...
